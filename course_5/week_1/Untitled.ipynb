# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %matplotlib inline

# %%
data = pd.read_csv('../week_1/monthly-milk-production.csv', sep=';')

# %%
data.head(5)
# Out:
#         month  milk
# 0  01.01.1962   589
# 1  01.02.1962   561
# 2  01.03.1962   640
# 3  01.04.1962   656
# 4  01.05.1962   727

# %%
milk = pd.read_csv('monthly-milk-production.csv',';', index_col=['month'], parse_dates=['month'], dayfirst=True)

# %%
milk.head(5)
# Out:
#             milk
# month
# 1962-01-01   589
# 1962-02-01   561
# 1962-03-01   640
# 1962-04-01   656
# 1962-05-01   727

# %%
plt.plot(milk);

# %%
import statsmodels.api as sm
sm.tsa.stattools.adfuller(milk['milk'])
# Out:
# (-1.3038115874221217,
#  0.6274267086030353,
#  13,
#  154,
#  {'1%': -3.473542528196209,
#   '5%': -2.880497674144038,
#   '10%': -2.576878053634677},
#  1115.1730447395112)

# %%
md = {'01': 31, '02': 28, '03': 31, '04': 30, '05': 31, '06': 30,
      '07': 31, '08': 31, '09': 30, '10': 31, '11': 30, '12': 31}

# %%
milk['date'] = data['month']

# %%
data['number of month'] = data['month'][4:2]

# %%
data
# Out:
#           month  milk number of month
# 0    01.01.1962   589             NaN
# 1    01.02.1962   561             NaN
# 2    01.03.1962   640             NaN
# 3    01.04.1962   656             NaN
# 4    01.05.1962   727             NaN
# 5    01.06.1962   697             NaN
# 6    01.07.1962   640             NaN
# 7    01.08.1962   599             NaN
# 8    01.09.1962   568             NaN
# 9    01.10.1962   577             NaN
# 10   01.11.1962   553             NaN
# 11   01.12.1962   582             NaN
# 12   01.01.1963   600             NaN
# 13   01.02.1963   566             NaN
# 14   01.03.1963   653             NaN
# 15   01.04.1963   673             NaN
# 16   01.05.1963   742             NaN
# 17   01.06.1963   716             NaN
# 18   01.07.1963   660             NaN
# 19   01.08.1963   617             NaN
# 20   01.09.1963   583             NaN
# 21   01.10.1963   587             NaN
# 22   01.11.1963   565             NaN
# 23   01.12.1963   598             NaN
# 24   01.01.1964   628             NaN
# 25   01.02.1964   618             NaN
# 26   01.03.1964   688             NaN
# 27   01.04.1964   705             NaN
# 28   01.05.1964   770             NaN
# 29   01.06.1964   736             NaN
# ..          ...   ...             ...
# 138  01.07.1973   881             NaN
# 139  01.08.1973   837             NaN
# 140  01.09.1973   784             NaN
# 141  01.10.1973   791             NaN
# 142  01.11.1973   760             NaN
# 143  01.12.1973   802             NaN
# 144  01.01.1974   828             NaN
# 145  01.02.1974   778             NaN
# 146  01.03.1974   889             NaN
# 147  01.04.1974   902             NaN
# 148  01.05.1974   969             NaN
# 149  01.06.1974   947             NaN
# 150  01.07.1974   908             NaN
# 151  01.08.1974   867             NaN
# 152  01.09.1974   815             NaN
# 153  01.10.1974   812             NaN
# 154  01.11.1974   773             NaN
# 155  01.12.1974   813             NaN
# 156  01.01.1975   834             NaN
# 157  01.02.1975   782             NaN
# 158  01.03.1975   892             NaN
# 159  01.04.1975   903             NaN
# 160  01.05.1975   966             NaN
# 161  01.06.1975   937             NaN
# 162  01.07.1975   896             NaN
# 163  01.08.1975   858             NaN
# 164  01.09.1975   817             NaN
# 165  01.10.1975   827             NaN
# 166  01.11.1975   797             NaN
# 167  01.12.1975   843             NaN
#
# [168 rows x 3 columns]

# %% [markdown]
# Корректно определить число дней в месяце можно с помощью свойства days_in_month у индекса ряда или функции monthrange из пакета calendar. Используйте число дней в месяце для того, чтобы вычислить новый показатель — среднее дневное число полученного молока на одну корову. Постройте график этого ряда и убедитесь, что он стал более гладким.
